# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhuri8199/Python-practice/blob/main/PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = { "Name": ["Madhuri", "teja", "prudvi", "meghana"], "Age": [22, 21, 24, 23], "City": ["Hyderabad", "Bangalore", "Chennai","pune"] }
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age       City
# 0  Madhuri   22  Hyderabad
# 1     teja   21  Bangalore
# 2   prudvi   24    Chennai
# 3  meghana   23       pune

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-17e1d1f2-0517-4832-b3bd-ac9a4507ca8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-17e1d1f2-0517-4832-b3bd-ac9a4507ca8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("coffee.csv")
print(df)
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ...          ...                      ...       ...                  ...
# 3631  2025-03-23  2025-03-23 10:34:54.894      card  ANON-0000-0000-1158
# 3632  2025-03-23  2025-03-23 14:43:37.362      card  ANON-0000-0000-1315
# 3633  2025-03-23  2025-03-23 14:44:16.864      card  ANON-0000-0000-1315
# 3634  2025-03-23  2025-03-23 15:47:28.723      card  ANON-0000-0000-1316
# 3635  2025-03-23  2025-03-23 18:11:38.635      card  ANON-0000-0000-1275
#
#       money    coffee_name
# 0     38.70          Latte
# 1     38.70  Hot Chocolate
# ...

# %%
import pandas as pd
df = [13,57,24,678,345]
f = pd.Series(df)
print(f)
# Out:
# 0     13
# 1     57
# 2     24
# 3    678
# 4    345
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv("coffee.csv")
f=df.iloc[0:10,0:3]
print(f)
# Out:
#          date                 datetime cash_type
# 0  2024-03-01  2024-03-01 10:15:50.520      card
# 1  2024-03-01  2024-03-01 12:19:22.539      card
# 2  2024-03-01  2024-03-01 12:20:18.089      card
# 3  2024-03-01  2024-03-01 13:46:33.006      card
# 4  2024-03-01  2024-03-01 13:48:14.626      card
# 5  2024-03-01  2024-03-01 15:39:47.726      card
# 6  2024-03-01  2024-03-01 16:19:02.756      card
# 7  2024-03-01  2024-03-01 18:39:03.580      card
# 8  2024-03-01  2024-03-01 19:22:01.762      card
# 9  2024-03-01  2024-03-01 19:23:15.887      card

# %%
import pandas as pd
df = pd.read_csv("coffee.csv")
row=df.index[0:15]
col=["money", "coffee_name"]
f=df.loc[row,col]
print(f)
# Out:
#     money          coffee_name
# 0    38.7                Latte
# 1    38.7        Hot Chocolate
# 2    38.7        Hot Chocolate
# 3    28.9            Americano
# 4    38.7                Latte
# 5    33.8  Americano with Milk
# 6    38.7        Hot Chocolate
# 7    33.8  Americano with Milk
# 8    38.7                Cocoa
# 9    33.8  Americano with Milk
# 10   33.8  Americano with Milk
# 11   28.9            Americano
# 12   40.0                Latte
# 13   33.8  Americano with Milk
# 14   33.8  Americano with Milk

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9bfd5c8d-8773-41b9-9ca1-946f61e8f2e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9bfd5c8d-8773-41b9-9ca1-946f61e8f2e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("coffee.csv")
result=df.sort_values( by = "coffee_name", ascending = False)
print(result)
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1518  2024-09-09  2024-09-09 20:13:43.524      card  ANON-0000-0000-0606
# 1575  2024-09-17  2024-09-17 08:09:00.896      card  ANON-0000-0000-0621
# 1571  2024-09-16  2024-09-16 21:11:32.500      card  ANON-0000-0000-0626
# 1569  2024-09-16  2024-09-16 18:56:05.275      card  ANON-0000-0000-0625
# ...          ...                      ...       ...                  ...
# 276   2024-04-13  2024-04-13 12:43:02.389      card  ANON-0000-0000-0012
# 3105  2025-02-15  2025-02-15 14:11:53.922      card  ANON-0000-0000-1215
# 997   2024-07-20  2024-07-20 08:07:51.433      card  ANON-0000-0000-0387
# 995   2024-07-20  2024-07-20 08:05:44.469      card  ANON-0000-0000-0387
# 2201  2024-11-03  2024-11-03 16:20:37.116      card  ANON-0000-0000-0852
#
#       money coffee_name
# 0     38.70       Latte
# 1518  32.82       Latte
# ...
